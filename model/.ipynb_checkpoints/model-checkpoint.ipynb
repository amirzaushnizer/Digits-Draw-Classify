# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.datasets import mnist

# %%
#Load dataset for the model
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

# %%
for i in range(9):  
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical

# %%
#Create categorical labels for the model

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
#Reshape imagesfrom 2d array to 1d array

X_train = np.reshape(X_train,(len(X_train), 28*28))
X_test = np.reshape(X_test,(len(X_test), 28*28))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(units=784,activation='relu'))
model.add(Dense(units=784,activation='relu'))
model.add(Dense(units=10,activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)

# %%
model.fit(x=X_train,
         y=y_train_cat,
         epochs=20,
         validation_data=(X_test, y_test_cat),
         verbose=1,
         callbacks=[early_stop])
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1791 - val_loss: 0.0892
# Epoch 2/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0824 - val_loss: 0.0819
# Epoch 3/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0579 - val_loss: 0.0754
# Epoch 4/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0438 - val_loss: 0.0911
# Epoch 5/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0345 - val_loss: 0.0929
# Epoch 00005: early stopping

# %%
#Plot training process

model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
predict_x=model.predict(X_test) 
predictions=np.argmax(predict_x,axis=1)

# %%
#Evaluating the model

from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(testY,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      0.97      0.98      1032
#            3       0.96      0.99      0.97      1010
#            4       0.99      0.97      0.98       982
#            5       0.99      0.96      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.97      0.98      0.98      1028
#            8       0.99      0.96      0.97       974
#            9       0.95      0.99      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
# [[ 974    1    1    0    0    0    3    0    0    1]
#  [   0 1124    1    2    0    3    2    2    1    0]
#  [   5    0 1002    6    3    1    2   12    1    0]
#  [   0    0    1  999    0    0    0    4    1    5]
#  [   1    0    2    0  956    0    6    2    0   15]
#  [   3    0    0   18    1  856    4    1    2    7]
#  [   7    3    0    1    1    6  939    0    1    0]
#  [   0    2    2    1    0    0    0 1011    1   11]
#  [   7    0    3   14    1    1    1    7  931    9]
#  [   0    2    0    3    5    0    1    2    1  995]]
